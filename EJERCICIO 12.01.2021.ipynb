# %%
metodox()
# Out:
# Metodo para las funciones
# x=0.25+0.25y
# y=0.25+0.25x+0.25z
# z=0.25+0.25y+0.25w
# w=0.25+0.25z
# [0, 0.25, 0.3125, 0.34375, 0.35546875, 0.3603515625, 0.3623046875, 0.36309814453125, 0.3634185791015625, 0.36354827880859375, 0.3636007308959961]
# [0, 0.25, 0.375, 0.421875, 0.44140625, 0.44921875, 0.452392578125, 0.45367431640625, 0.454193115234375, 0.4544029235839844, 0.45448780059814453]
# [0, 0.25, 0.375, 0.421875, 0.44140625, 0.44921875, 0.452392578125, 0.45367431640625, 0.454193115234375, 0.4544029235839844, 0.45448780059814453]
# [0, 0.25, 0.3125, 0.34375, 0.35546875, 0.3603515625, 0.3623046875, 0.36309814453125, 0.3634185791015625, 0.36354827880859375, 0.3636007308959961]

# %%
def gx(y):
    return (0.25+(0.25*y))
def gy(x, z):
  return (0.25+(0.25*x)+(0.25*z))
def gz(y, w):
  return (0.25+(0.25*y)+(0.25*w))
def gw(z):
  return (0.25+(0.25*z))

# %%
import matplotlib.pyplot as plt
import math
def metodox():
  print("Metodo para las funciones")
  print("x=0.25+0.25y")
  print("y=0.25+0.25x+0.25z")
  print("z=0.25+0.25y+0.25w")
  print("w=0.25+0.25z")
  fg1p()

def fg1p():
  x_vec=[]
  x_vec.append(0)
  y_vec=[]
  y_vec.append(0)
  z_vec=[]
  z_vec.append(0)
  w_vec=[]
  w_vec.append(0)
  contador = 0
  while(contador < 10):
    x_vec.append(gx(y_vec[contador]))
    y_vec.append(gy(x_vec[contador],z_vec[contador]))
    z_vec.append(gz(y_vec[contador],w_vec[contador]))
    w_vec.append(gw(z_vec[contador]))
    contador += 1
  print(x_vec)
  print(y_vec)
  print(z_vec)
  print(w_vec)
  plt.plot(x_vec, label = "x_r")
  plt.plot(y_vec, label = "x_y")
  plt.plot(z_vec, label = "x_z")
  plt.plot(w_vec, label = "x_w")
  plt.legend()
  plt.show()
