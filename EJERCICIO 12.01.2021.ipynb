# %%
metodox()
# Out:
# Metodo para las funciones
# x=0.25+0.25y
# y=0.25+0.25x+0.25z
# z=0.25+0.25y+0.25w
# w=0.25+0.25z
# xinicial = 3
# [0, 0.25, 0.3125, 0.328125, 0.33203125, 0.3330078125, 0.333251953125, 0.33331298828125, 0.3333282470703125, 0.3333320617675781, 0.33333301544189453]
# [0, 0.25, 0.375, 0.421875, 0.4375, 0.443359375, 0.4453125, 0.446044921875, 0.4462890625, 0.446380615234375, 0.4464111328125]
# [0, 0.25, 0.375, 0.421875, 0.44140625, 0.4482421875, 0.450927734375, 0.45184326171875, 0.4521942138671875, 0.4523124694824219, 0.45235729217529297]
# [0, 0.25, 0.3125, 0.34375, 0.35546875, 0.3603515625, 0.362060546875, 0.36273193359375, 0.3629608154296875, 0.3630485534667969, 0.36307811737060547]

# %%
def gx(y):
    return (0.25+(0.25*y))
def gy(x, z):
  return (0.25+(0.25*x)+(0.25*z))
def gz(y, w):
  return (0.25+(0.25*y)+(0.25*w))
def gw(z):
  return (0.25+(0.25*z))

# %%
import matplotlib.pyplot as plt
import math
def metodox():
  print("Metodo para las funciones")
  print("x=0.25+0.25y")
  print("y=0.25+0.25x+0.25z")
  print("z=0.25+0.25y+0.25w")
  print("w=0.25+0.25z")
  print("xinicial = 3")
  fg1p()

def fg1p():
  x_vec=[]
  x_vec.append(0)
  y_vec=[]
  y_vec.append(0)
  z_vec=[]
  z_vec.append(0)
  w_vec=[]
  w_vec.append(0)
  contador = 0
  while(contador < 10):
    x_vec.append(gx(x_vec[contador]))
    y_vec.append(gy(x_vec[contador],z_vec[contador]))
    z_vec.append(gz(y_vec[contador],w_vec[contador]))
    w_vec.append(gw(z_vec[contador]))
    contador += 1
  print(x_vec)
  print(y_vec)
  print(z_vec)
  print(w_vec)
  plt.plot(x_vec, label = "x_r")
  plt.plot(y_vec, label = "x_y")
  plt.plot(z_vec, label = "x_z")
  plt.plot(w_vec, label = "x_w")
  plt.legend()
  plt.show()
